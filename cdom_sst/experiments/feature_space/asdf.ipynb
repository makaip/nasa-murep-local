# %% [markdown]
# todo's
#  - moving window average? (7-day), 14 day?
#  - intelligently select standard deviation
#  - monthly subplot of histograms of temperatures
#  - subset data by bathymetry? (above 200m)
#
# look at color temperature images / histogram
#
# ---
#
# end goal
# use maps to segment CDOM, obtain metrics
# look at plots
